# %% [markdown]
# <a href="https://colab.research.google.com/github/minhtam3010050-jpg/TH_DEEP/blob/main/BT_TUAN4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.1. Nạp thư viện

# %%
from keras.datasets import mnist
import numpy as np
import keras
from keras import layers

# %% [markdown]
# 2.2. Nạp dataset

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 784)
# (10000, 784)

# %% [markdown]
# 2.3. Xây dựng mô hình Autoencoder

# %%
encoding_dim = 32

input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# 2.4. Huấn luyện mô hình

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0102 - loss: 0.2750 - val_accuracy: 0.0105 - val_loss: 0.1895
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0114 - loss: 0.1721 - val_accuracy: 0.0126 - val_loss: 0.1553
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0101 - loss: 0.1456 - val_accuracy: 0.0106 - val_loss: 0.1344
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0100 - loss: 0.1284 - val_accuracy: 0.0102 - val_loss: 0.1209
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0108 - loss: 0.1177 - val_accuracy: 0.0099 - val_loss: 0.1124
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0116 - loss: 0.1106 - val_accuracy: 0.0107 - val_loss: 0.1065
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0114 - loss: 0.1056 - val_accuracy: 0.0125 - val_loss: 0.1023
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0116 - loss: 0.1019 - val_accuracy: 0.0122 - val_loss: 0.0992
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0116 - loss: 0.0993 - val_accuracy: 0.0125 - val_loss: 0.0971
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0115 - loss: 0.0974 - val_accuracy: 0.0122 - val_loss: 0.0954
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0117 - loss: 0.0962 - val_accuracy: 0.0123 - val_loss: 0.0944
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0121 - loss: 0.0954 - val_accuracy: 0.0130 - val_loss: 0.0938
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0114 - loss: 0.0948 - val_accuracy: 0.0134 - val_loss: 0.0934
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0115 - loss: 0.0945 - val_accuracy: 0.0134 - val_loss: 0.0931
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0113 - loss: 0.0942 - val_accuracy: 0.0137 - val_loss: 0.0928
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0115 - loss: 0.0940 - val_accuracy: 0.0131 - val_loss: 0.0927
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0114 - loss: 0.0938 - val_accuracy: 0.0135 - val_loss: 0.0925
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0117 - loss: 0.0937 - val_accuracy: 0.0108 - val_loss: 0.0925
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0115 - loss: 0.0936 - val_accuracy: 0.0116 - val_loss: 0.0923
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0118 - loss: 0.0935 - val_accuracy: 0.0120 - val_loss: 0.0923
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0117 - loss: 0.0934 - val_accuracy: 0.0118 - val_loss: 0.0923
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0115 - loss: 0.0933 - val_accuracy: 0.0131 - val_loss: 0.0922
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0115 - loss: 0.0933 - val_accuracy: 0.0133 - val_loss: 0.0921
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0114 - loss: 0.0932 - val_accuracy: 0.0128 - val_loss: 0.0921
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0116 - loss: 0.0932 - val_accuracy: 0.0130 - val_loss: 0.0920
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0115 - loss: 0.0931 - val_accuracy: 0.0126 - val_loss: 0.0920
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.0115 - loss: 0.0931 - val_accuracy: 0.0136 - val_loss: 0.0919
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0112 - loss: 0.0931 - val_accuracy: 0.0129 - val_loss: 0.0919
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.0113 - loss: 0.0930 - val_accuracy: 0.0122 - val_loss: 0.0919
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0113 - loss: 0.0930 - val_accuracy: 0.0135 - val_loss: 0.0919
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.0113 - loss: 0.0930 - val_accuracy: 0.0125 - val_loss: 0.0919
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.0115 - loss: 0.0930 - val_accuracy: 0.0129 - val_loss: 0.0919
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.0116 - loss: 0.0929 - val_accuracy: 0.0122 - val_loss: 0.0918
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0113 - loss: 0.0929 - val_accuracy: 0.0141 - val_loss: 0.0918
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0117 - loss: 0.0929 - val_accuracy: 0.0123 - val_loss: 0.0918
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.0117 - loss: 0.0929 - val_accuracy: 0.0128 - val_loss: 0.0918
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0117 - loss: 0.0929 - val_accuracy: 0.0128 - val_loss: 0.0919
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.0116 - loss: 0.0928 - val_accuracy: 0.0124 - val_loss: 0.0917
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0115 - loss: 0.0928 - val_accuracy: 0.0112 - val_loss: 0.0918
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0117 - loss: 0.0928 - val_accuracy: 0.0127 - val_loss: 0.0917
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.0118 - loss: 0.0928 - val_accuracy: 0.0128 - val_loss: 0.0917
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0120 - loss: 0.0928 - val_accuracy: 0.0120 - val_loss: 0.0918
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0118 - loss: 0.0928 - val_accuracy: 0.0117 - val_loss: 0.0917
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0120 - loss: 0.0927 - val_accuracy: 0.0126 - val_loss: 0.0917
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0119 - loss: 0.0927 - val_accuracy: 0.0123 - val_loss: 0.0917
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.0118 - loss: 0.0927 - val_accuracy: 0.0117 - val_loss: 0.0917
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.0116 - loss: 0.0927 - val_accuracy: 0.0132 - val_loss: 0.0917
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.0119 - loss: 0.0927 - val_accuracy: 0.0130 - val_loss: 0.0917
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0117 - loss: 0.0927 - val_accuracy: 0.0124 - val_loss: 0.0916
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - accuracy: 0.0114 - loss: 0.0927 - val_accuracy: 0.0124 - val_loss: 0.0916

# %% [markdown]
# 2.5. Dự báo loại ảnh sử dụng Autoencoder

# %%
encoded_ims = encoder.predict(x_test)
decoded_ims = decoder.predict(encoded_ims)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# 2.6. Hiển thị ảnh từ mô hình Autoencoder

# %%
import matplotlib.pyplot as plt

decoded_ims = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_ims[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# 3.1. Thêm L1

# %%
from tensorflow.keras import regularizers
encoding_dim = 32
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activity_regularizer=regularizers.l1(10e-5), activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256, verbose=1,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0143 - loss: 0.6554 - val_accuracy: 0.0161 - val_loss: 0.6155
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.5832 - val_accuracy: 0.0161 - val_loss: 0.5535
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.0150 - loss: 0.5275 - val_accuracy: 0.0161 - val_loss: 0.5038
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.4827 - val_accuracy: 0.0161 - val_loss: 0.4638
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.4466 - val_accuracy: 0.0161 - val_loss: 0.4314
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.4174 - val_accuracy: 0.0161 - val_loss: 0.4050
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0146 - loss: 0.3935 - val_accuracy: 0.0161 - val_loss: 0.3834
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.3739 - val_accuracy: 0.0161 - val_loss: 0.3656
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.3577 - val_accuracy: 0.0161 - val_loss: 0.3508
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.0150 - loss: 0.3442 - val_accuracy: 0.0161 - val_loss: 0.3385
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0148 - loss: 0.3329 - val_accuracy: 0.0161 - val_loss: 0.3281
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.3234 - val_accuracy: 0.0161 - val_loss: 0.3194
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.3154 - val_accuracy: 0.0161 - val_loss: 0.3120
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.3086 - val_accuracy: 0.0161 - val_loss: 0.3056
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.0148 - loss: 0.3027 - val_accuracy: 0.0161 - val_loss: 0.3002
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2977 - val_accuracy: 0.0161 - val_loss: 0.2955
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.0148 - loss: 0.2934 - val_accuracy: 0.0161 - val_loss: 0.2915
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2897 - val_accuracy: 0.0161 - val_loss: 0.2880
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2865 - val_accuracy: 0.0161 - val_loss: 0.2850
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.0148 - loss: 0.2836 - val_accuracy: 0.0161 - val_loss: 0.2823
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2812 - val_accuracy: 0.0161 - val_loss: 0.2800
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0144 - loss: 0.2790 - val_accuracy: 0.0161 - val_loss: 0.2780
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.0145 - loss: 0.2772 - val_accuracy: 0.0161 - val_loss: 0.2762
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0150 - loss: 0.2755 - val_accuracy: 0.0161 - val_loss: 0.2747
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0137 - loss: 0.2741 - val_accuracy: 0.0161 - val_loss: 0.2733
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.0150 - loss: 0.2728 - val_accuracy: 0.0161 - val_loss: 0.2721
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2717 - val_accuracy: 0.0161 - val_loss: 0.2710
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.0150 - loss: 0.2707 - val_accuracy: 0.0161 - val_loss: 0.2700
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0149 - loss: 0.2698 - val_accuracy: 0.0161 - val_loss: 0.2692
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.0150 - loss: 0.2690 - val_accuracy: 0.0161 - val_loss: 0.2685
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2683 - val_accuracy: 0.0161 - val_loss: 0.2678
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2677 - val_accuracy: 0.0161 - val_loss: 0.2672
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0146 - loss: 0.2672 - val_accuracy: 0.0161 - val_loss: 0.2667
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2667 - val_accuracy: 0.0161 - val_loss: 0.2663
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0150 - loss: 0.2663 - val_accuracy: 0.0161 - val_loss: 0.2658
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2659 - val_accuracy: 0.0161 - val_loss: 0.2655
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2656 - val_accuracy: 0.0161 - val_loss: 0.2652
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0149 - loss: 0.2653 - val_accuracy: 0.0143 - val_loss: 0.2649
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0148 - loss: 0.2650 - val_accuracy: 0.0161 - val_loss: 0.2646
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2648 - val_accuracy: 0.0161 - val_loss: 0.2644
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2645 - val_accuracy: 0.0161 - val_loss: 0.2642
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2644 - val_accuracy: 0.0161 - val_loss: 0.2640
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0150 - loss: 0.2642 - val_accuracy: 0.0161 - val_loss: 0.2638
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0148 - loss: 0.2640 - val_accuracy: 0.0161 - val_loss: 0.2637
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2639 - val_accuracy: 0.0161 - val_loss: 0.2636
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0150 - loss: 0.2638 - val_accuracy: 0.0161 - val_loss: 0.2635
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0148 - loss: 0.2637 - val_accuracy: 0.0161 - val_loss: 0.2634
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2636 - val_accuracy: 0.0161 - val_loss: 0.2633
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2635 - val_accuracy: 0.0161 - val_loss: 0.2632
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2634 - val_accuracy: 0.0161 - val_loss: 0.2631
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2634 - val_accuracy: 0.0161 - val_loss: 0.2630
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0148 - loss: 0.2633 - val_accuracy: 0.0161 - val_loss: 0.2630
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2632 - val_accuracy: 0.0161 - val_loss: 0.2629
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2632 - val_accuracy: 0.0161 - val_loss: 0.2629
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0143 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0148 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0138 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.0146 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0144 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625

# %% [markdown]
# 3.2. Thêm layers

# %%
encoding_dim = 32
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(encoding_dim, activation='relu')(encoded)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(32,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# BAI TAP

# %% [markdown]
# Viết chương trình cài đặt Autoencoder để nhận dạng ảnh trên bộ dataset CIFAR10 có sẵn trong
# tensorflow với các nhãn sau

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import numpy as np

(x_train, _), (x_test, _) = datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

input_img = layers.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=10,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 133s 335ms/step - loss: 0.5837 - val_loss: 0.5682
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 131s 336ms/step - loss: 0.5649 - val_loss: 0.5662
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 336ms/step - loss: 0.5625 - val_loss: 0.5624
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 127s 324ms/step - loss: 0.5613 - val_loss: 0.5617
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 146s 335ms/step - loss: 0.5605 - val_loss: 0.5610
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 129s 329ms/step - loss: 0.5598 - val_loss: 0.5603
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 127s 325ms/step - loss: 0.5594 - val_loss: 0.5601
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 128s 328ms/step - loss: 0.5589 - val_loss: 0.5595
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 135s 344ms/step - loss: 0.5586 - val_loss: 0.5591
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 147s 356ms/step - loss: 0.5584 - val_loss: 0.5589

# %% [markdown]
# **RNN**

# %% [markdown]
# 2.1. Nạp thư viện

# %%
from pandas import read_csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt

# %% [markdown]
# 2.2. Tạo hàm định nghĩa mô hình RNN

# %%
def create_RNN(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(SimpleRNN(hidden_units, input_shape=input_shape, activation=activation[0]))
    model.add(Dense(dense_units, activation=activation[1]))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

demo_RNN = create_RNN(2, 1, (3, 1), ['linear', 'linear'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# 2.3. Xem các tham số sinh bởi RNN

# %%
wx = demo_RNN.get_weights()[0]
wh = demo_RNN.get_weights()[1]
bh = demo_RNN.get_weights()[2]
wy = demo_RNN.get_weights()[3]
by = demo_RNN.get_weights()[4]

print('wx=', wx)
print('wh=', wh)
print('bh=', bh)
print('wy=', wy)
print('by=', by)
# Out:
# wx= [[0.78269184 1.1578985 ]]
# wh= [[-0.46107662 -0.88736033]
#  [ 0.88736033 -0.46107662]]
# bh= [0. 0.]
# wy= [[ 0.6077751]
#  [-1.2743902]]
# by= [0.]

# %% [markdown]
# 2.4. Tính vector hidden cho tầng recurrent

# %%
x = np.array([1, 2, 3])
x_input = np.reshape(x, (1, 3, 1))
y_predict_model = demo_RNN.predict(x_input)

m = 2
h0 = np.zeros(m)
h1 = np.dot(x[0], wx) + bh + h0
h2 = np.dot(x[1], wx) + np.dot(h1, wh) + bh
h3 = np.dot(x[2], wx) + np.dot(h2, wh) + bh

o3 = np.dot(h3, wy) + by

print('h1:', h1)
print('h2:', h2)
print('h3:', h3)

print('Prediction of model:', y_predict_model)
print('Prediction from computation:', o3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# h1: [[0.78269184 1.15789855]]
# h2: [[2.23197601 1.08738746]]
# h3: [[2.28386806 0.99175973]]
# Prediction of model: [[0.12418902]]
# Prediction from computation: [[0.12418922]]

# %% [markdown]
# 3.1. Đọc dữ liệu

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
# XÓA HOẶC COMMENT DÒNG DƯỚI ĐÂY:
# from keras import engine

def get_train_test(url, split_percent=0.8):
    df = pd.read_csv(url, usecols=[1], engine='python')
    data = np.array(df.values.astype('float32'))
    scaler = MinMaxScaler(feature_range=(0, 1))
    data = scaler.fit_transform(data).flatten()

    n = len(data)

    split = int(n * split_percent)
    train_data = data[range(split)]
    test_data = data[split:]
    return train_data, test_data, data

sunspots_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv'
train_data, test_data, data = get_train_test(sunspots_url)

# %% [markdown]
# 3.2. Chuẩn bị dữ liệ

# %%
def get_XY(dat, time_steps):
    #indices target arrays
    y_ind = np.arange(time_steps, len(dat), time_steps)
    Y = dat[y_ind]

    #prepare X
    row_x = len(Y)
    X = dat[range(time_steps * row_x)]
    X = np.reshape(X, (row_x, time_steps, 1))
    return X, Y

time_steps = 12
trainX, trainY = get_XY(train_data, time_steps)
testX, testY = get_XY(test_data, time_steps)

# %% [markdown]
# 3.3. Tạo RNN model và huấn luyện

# %%
model = create_RNN(hidden_units=3, dense_units=1, input_shape=(time_steps,1), activation=['tanh','tanh'])
model_fit = model.fit(trainX, trainY, epochs=20, verbose =1)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2975
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2524
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2142
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1809
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1532
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1298
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1123
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0984
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0870
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0790
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0723
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0666
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0622
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0584
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0548
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0516
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0488
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0461
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0436
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0414

# %% [markdown]
# 3.4. Hàm tính hiệu quả model

# %%
def print_error(trainY, testY, train_predict, test_predict):
    train_rmse = math.sqrt(mean_squared_error(trainY, train_predict))
    test_rmse = math.sqrt(mean_squared_error(testY, test_predict))
    print('Train RMSE: %.3f RMSE' % (train_rmse))
    print('Test RMSE: %.3f RMSE' % (test_rmse))

train_predict = model.predict(trainX)
test_predict = model.predict(testX)

print_error(trainY, testY, train_predict, test_predict)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Train RMSE: 0.200 RMSE
# Test RMSE: 0.336 RMSE

# %% [markdown]
# 3.5. Đánh giá kết quả

# %%
def plot_result(trainY, testY, train_predict, test_predict):
    actual = np.append(trainY, testY)
    predictions = np.append(train_predict, test_predict)
    rows = len(actual)
    plt.figure(figsize=(15, 6), dpi=80)
    plt.plot(range(rows), actual)
    plt.plot(range(rows), predictions)
    plt.axvline(x=len(trainY), color='r')
    plt.legend(['Actual', 'Predictions'])
    plt.xlabel('Observation number after given time steps')
    plt.ylabel('Sunspots scaled')
    plt.title('Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
    plt.show()

plot_result(trainY, testY, train_predict, test_predict)
